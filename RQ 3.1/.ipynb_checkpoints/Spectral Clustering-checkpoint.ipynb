# %%
# %matplotlib inline 
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.metrics import classification_report


#K-Means import
from sklearn import metrics
from sklearn.cluster import KMeans
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

from time import time
import numpy as np
import matplotlib.pyplot as plt


from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import pairwise_distances
from sklearn.cluster import SpectralClustering

# %%
def bench_hierarchical(estimator, name, data,labels=None):
    t0 = time()
    estimator.fit(data)
    print('%-9s\t%.2fs\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f'
          % (name, (time() - t0), 
             metrics.homogeneity_score(labels, estimator.labels_),
             metrics.completeness_score(labels, estimator.labels_),
             metrics.v_measure_score(labels, estimator.labels_),
             metrics.adjusted_rand_score(labels, estimator.labels_),
             metrics.adjusted_mutual_info_score(labels,  estimator.labels_),
             metrics.silhouette_score(data, estimator.labels_,
                                      metric='euclidean',
                                      sample_size=None)))
    return estimator

# %% [markdown]
# # Aggolomerative Fold 1

# %%
from sklearn.dummy import DummyClassifier
traindata=pd.read_csv("./test1.tsv",delimiter="\t")
X_test=traindata.text.values
Y_test=np.array(traindata.label.values).astype(np.int32)

traindata=pd.read_csv("./train1.tsv",delimiter="\t")
X_train=traindata.text.values
Y_train=np.array(traindata.label.values).astype(np.int32)
clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,2))), ('tfidf', TfidfTransformer(use_idf=True))])
clf.fit(X_train)


X_train=(clf.transform(X_train)).toarray()
X_test=clf.transform(X_test).toarray()

data=X_test
labels=np.array(Y_test)-1
# print(labels)

# Do K-Means
for rstate in [1]:
    
    print("Random State", rstate)
    
    print(82 * '_')
    print('init\t\ttime\thomo\tcompl\tv-meas\tARI\tAMI\tsilhouette')
    km1_km=bench_hierarchical(SpectralClustering(n_clusters=4,random_state=rstate,assign_labels="kmeans"), name="K-Means", data=data,labels=labels)

    km1_random=bench_hierarchical(SpectralClustering(n_clusters=4,random_state=rstate,assign_labels="discretize"), name="Discritize", data=data,labels=labels)
    
  
    print(82 * '_')


    print("Cosine Affinity")
    ypred=km1_km.labels_
    print(classification_report(np.array(Y_test)-1,ypred,digits=5))

    print("Euclidean Affinity")
    ypred=km1_random.labels_
    print(classification_report(np.array(Y_test)-1,ypred,digits=5))
# Out:
# Random State 1
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.09s	0.036	0.048	0.041	0.002	0.016	0.010
# Discritize	0.05s	0.040	0.043	0.042	0.000	0.019	0.008
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.32051   0.43103   0.36765        58
#            1    0.48980   0.53333   0.51064        90
#            2    0.00000   0.00000   0.00000        12
#            3    0.60000   0.12500   0.20690        24
#
#     accuracy                        0.41304       184
#    macro avg    0.35258   0.27234   0.27130       184
# weighted avg    0.41887   0.41304   0.39264       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.31579   0.41379   0.35821        58
#            1    1.00000   0.05556   0.10526        90
#            2    0.00000   0.00000   0.00000        12
#            3    0.12658   0.41667   0.19417        24
#
#     accuracy                        0.21196       184
#    macro avg    0.36059   0.22150   0.16441       184
# weighted avg    0.60518   0.21196   0.18973       184

# %% [markdown]
# # Aggolomerative Fold 2

# %%
from sklearn.dummy import DummyClassifier
traindata=pd.read_csv("./test2.tsv",delimiter="\t")
X_test=traindata.text.values
Y_test=np.array(traindata.label.values).astype(np.int32)

traindata=pd.read_csv("./train2.tsv",delimiter="\t")
X_train=traindata.text.values
Y_train=np.array(traindata.label.values).astype(np.int32)
clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,2))), ('tfidf', TfidfTransformer(use_idf=True))])
clf.fit(X_train)


X_train=(clf.transform(X_train)).toarray()
X_test=clf.transform(X_test).toarray()

data=X_test
labels=np.array(Y_test)-1
# print(labels)

# Do K-Means
for rstate in [41]:
    
    print("Random State", rstate)
    
    print(82 * '_')
    print('init\t\ttime\thomo\tcompl\tv-meas\tARI\tAMI\tsilhouette')
    km1_km=bench_hierarchical(SpectralClustering(n_clusters=4,random_state=rstate,assign_labels="kmeans"), name="K-Means", data=data,labels=labels)

    km1_random=bench_hierarchical(SpectralClustering(n_clusters=4,random_state=rstate,assign_labels="discretize"), name="Discritize", data=data,labels=labels)
    
  
    print(82 * '_')


    print("Cosine Affinity")
    ypred=km1_km.labels_
    print(classification_report(np.array(Y_test)-1,ypred,digits=5))

    print("Euclidean Affinity")
    ypred=km1_random.labels_
    print(classification_report(np.array(Y_test)-1,ypred,digits=5))
# Out:
# Random State 41
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.09s	0.038	0.059	0.046	-0.034	0.020	0.010
# Discritize	0.05s	0.016	0.017	0.016	-0.023	-0.007	0.009
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.29710   0.73214   0.42268        56
#            1    0.84615   0.12222   0.21359        90
#            2    0.03226   0.06667   0.04348        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.28804       184
#    macro avg    0.29388   0.23026   0.16994       184
# weighted avg    0.50693   0.28804   0.23666       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.40816   0.35714   0.38095        56
#            1    0.64000   0.17778   0.27826        90
#            2    0.07692   0.06667   0.07143        15
#            3    0.15464   0.65217   0.25000        23
#
#     accuracy                        0.28261       184
#    macro avg    0.31993   0.31344   0.24516       184
# weighted avg    0.46287   0.28261   0.28912       184

# %% [markdown]
# # Aggolomerative with Learnt BERT Representations

# %%
import pickle

X_train= pickle.load(open('./bert_features/fold1/xtrain.pkl', 'rb'))
Y_train= pickle.load(open('./bert_features/fold1/ytrain.pkl', 'rb'))
X_test= pickle.load(open('./bert_features/fold1/xtest.pkl', 'rb'))
Y_test= pickle.load(open('./bert_features/fold1/ytest.pkl', 'rb'))






data=X_test
labels=np.array(Y_test)
# print(labels)

# Do K-Means
for rstate in [6]:#,16,21,31]:
    
    print("Random State", rstate)
    
    print(82 * '_')
    print('init\t\ttime\thomo\tcompl\tv-meas\tARI\tAMI\tsilhouette')
    km1_km=bench_hierarchical(SpectralClustering(n_clusters=4,random_state=rstate,assign_labels="kmeans"), name="K-Means", data=data,labels=labels)

    km1_random=bench_hierarchical(SpectralClustering(n_clusters=4,random_state=rstate,assign_labels="discretize"), name="Discritize", data=data,labels=labels)
    
  
    print(82 * '_')


    print("Cosine Affinity")
    ypred=km1_km.labels_
    print(classification_report(np.array(Y_test),ypred,digits=5))

    print("Euclidean Affinity")
    ypred=km1_random.labels_
    print(classification_report(np.array(Y_test),ypred,digits=5))
# Out:
# Random State 6
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.011	0.015	0.013	0.033	-0.014	0.097
# Discritize	0.02s	0.019	0.030	0.023	0.008	-0.006	0.063
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.36667   0.18966   0.25000        58
#            1    0.52713   0.75556   0.62100        90
#            2    0.13636   0.25000   0.17647        12
#            3    0.33333   0.04167   0.07407        24
#
#     accuracy                        0.45109       184
#    macro avg    0.34087   0.30922   0.28039       184
# weighted avg    0.42579   0.45109   0.40373       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30496   0.74138   0.43216        58
#            1    0.28571   0.02222   0.04124        90
#            2    0.00000   0.00000   0.00000        12
#            3    0.13333   0.16667   0.14815        24
#
#     accuracy                        0.26630       184
#    macro avg    0.18100   0.23257   0.15539       184
# weighted avg    0.25327   0.26630   0.17572       184

# %%
import pickle

X_train= pickle.load(open('./bert_features/fold2/xtrain.pkl', 'rb'))
Y_train= pickle.load(open('./bert_features/fold2/ytrain.pkl', 'rb'))
X_test= pickle.load(open('./bert_features/fold2/xtest.pkl', 'rb'))
Y_test= pickle.load(open('./bert_features/fold2/ytest.pkl', 'rb'))


data=X_test
labels=np.array(Y_test)
# print(labels)

# Do K-Means
for rstate in [6]:
    
    print("Random State", rstate)
    
    print(82 * '_')
    print('init\t\ttime\thomo\tcompl\tv-meas\tARI\tAMI\tsilhouette')
    km1_km=bench_hierarchical(SpectralClustering(n_clusters=4,random_state=rstate,assign_labels="kmeans"), name="K-Means", data=data,labels=labels)

    km1_random=bench_hierarchical(SpectralClustering(n_clusters=4,random_state=rstate,assign_labels="discretize"), name="Discritize", data=data,labels=labels)
    
  
    print(82 * '_')


    print("Cosine Affinity")
    ypred=km1_km.labels_
    print(classification_report(np.array(Y_test),ypred,digits=5))

    print("Euclidean Affinity")
    ypred=km1_random.labels_
    print(classification_report(np.array(Y_test),ypred,digits=5))
# Out:
# Random State 0
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.025	0.063	0.036	-0.013	0.007	0.280
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.28931   0.82143   0.42791        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    1.00000   0.04348   0.08333        23
#
#     accuracy                        0.26087       184
#    macro avg    0.40566   0.21900   0.13319       184
# weighted avg    0.37609   0.26087   0.15117       184
#
# Random State 1
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.022	0.049	0.030	-0.022	-0.001	0.022
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29299   0.82143   0.43192        56
#            1    0.25000   0.01111   0.02128        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.13575   0.20813   0.11330       184
# weighted avg    0.21145   0.25543   0.14186       184
#
# Random State 2
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.05s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.05s	0.022	0.049	0.030	-0.022	-0.001	0.022
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29299   0.82143   0.43192        56
#            1    0.25000   0.01111   0.02128        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.13575   0.20813   0.11330       184
# weighted avg    0.21145   0.25543   0.14186       184
#
# Random State 3
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.04s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.028	0.060	0.038	-0.029	0.008	0.034
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29677   0.82143   0.43602        56
#            1    0.25000   0.01111   0.02128        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.09524   0.08696   0.09091        23
#
#     accuracy                        0.26630       184
#    macro avg    0.16050   0.22987   0.13705       184
# weighted avg    0.22451   0.26630   0.15447       184
#
# Random State 4
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.023	0.054	0.032	-0.028	0.001	0.009
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29114   0.82143   0.42991        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15612   0.20813   0.11285       184
# weighted avg    0.25165   0.25543   0.14136       184
#
# Random State 5
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.05s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.05s	0.027	0.058	0.037	-0.026	0.006	0.212
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29487   0.82143   0.43396        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.10000   0.08696   0.09302        23
#
#     accuracy                        0.26630       184
#    macro avg    0.18205   0.22987   0.13712       184
# weighted avg    0.26529   0.26630   0.15422       184
#
# Random State 6
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.026	0.063	0.037	-0.020	0.009	0.257
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.34783   0.14286   0.20253        56
#            1    0.48408   0.84444   0.61538        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.45652       184
#    macro avg    0.20798   0.24683   0.20448       184
# weighted avg    0.34264   0.45652   0.36264       184
#
# Random State 7
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.07s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.022	0.052	0.031	-0.019	0.000	0.021
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29114   0.82143   0.42991        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15612   0.20813   0.11285       184
# weighted avg    0.25165   0.25543   0.14136       184
#
# Random State 8
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.05s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.05s	0.027	0.057	0.037	-0.030	0.006	0.215
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.38095   0.14286   0.20779        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.09677   1.00000   0.17647        15
#            3    0.20000   0.04348   0.07143        23
#
#     accuracy                        0.13587       184
#    macro avg    0.25276   0.29936   0.11930       184
# weighted avg    0.31187   0.13587   0.09707       184
#
# Random State 9
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.015	0.153	0.028	0.006	0.004	0.520
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.15833   0.24385   0.11978       184
# weighted avg    0.25435   0.29891   0.14980       184
#
# Random State 10
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.022	0.051	0.031	-0.022	0.000	0.024
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29299   0.82143   0.43192        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15658   0.20813   0.11336       184
# weighted avg    0.25222   0.25543   0.14197       184
#
# Random State 11
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.016	0.043	0.023	-0.020	0.001	0.270
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.38095   0.14286   0.20779        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.09375   1.00000   0.17143        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.13043       184
#    macro avg    0.20201   0.28849   0.10018       184
# weighted avg    0.28663   0.13043   0.08774       184
#
# Random State 12
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.015	0.040	0.022	-0.014	0.001	0.310
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.00000   0.00000   0.00000        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.12579   0.86957   0.21978        23
#
#     accuracy                        0.11413       184
#    macro avg    0.11478   0.22017   0.06032       184
# weighted avg    0.17877   0.11413   0.03799       184
#
# Random State 13
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.025	0.063	0.036	-0.013	0.007	0.280
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.28931   0.82143   0.42791        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    1.00000   0.04348   0.08333        23
#
#     accuracy                        0.26087       184
#    macro avg    0.40566   0.21900   0.13319       184
# weighted avg    0.37609   0.26087   0.15117       184
#
# Random State 14
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.029	0.062	0.039	-0.030	0.009	0.037
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29677   0.82143   0.43602        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15753   0.20813   0.11438       184
# weighted avg    0.25337   0.25543   0.14322       184
#
# Random State 15
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.015	0.153	0.028	0.006	0.004	0.520
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.15833   0.24385   0.11978       184
# weighted avg    0.25435   0.29891   0.14980       184
#
# Random State 16
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.016	0.040	0.023	-0.021	0.002	0.286
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29299   0.82143   0.43192        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15658   0.20813   0.11336       184
# weighted avg    0.25222   0.25543   0.14197       184
#
# Random State 17
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.028	0.151	0.048	-0.011	0.014	0.009
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30682   0.96429   0.46552        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    1.00000   0.04348   0.08333        23
#
#     accuracy                        0.30435       184
#    macro avg    0.41004   0.25472   0.14259       184
# weighted avg    0.38142   0.30435   0.16261       184
#
# Random State 18
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.05s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.029	0.064	0.040	-0.036	0.010	0.022
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29487   0.82143   0.43396        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15705   0.20813   0.11387       184
# weighted avg    0.25279   0.25543   0.14259       184
#
# Random State 19
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.05s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.015	0.153	0.028	0.006	0.004	0.520
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.15833   0.24385   0.11978       184
# weighted avg    0.25435   0.29891   0.14980       184
#
# Random State 20
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.04s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.029	0.064	0.040	-0.036	0.010	0.022
# __________________________________________________________________________________
# Cosine Affinity
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29487   0.82143   0.43396        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15705   0.20813   0.11387       184
# weighted avg    0.25279   0.25543   0.14259       184
#
# Random State 21
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.04s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.05s	0.025	0.058	0.035	-0.021	0.006	0.240
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29299   0.82143   0.43192        56
#            1    0.60000   0.03333   0.06316        90
#            2    0.00000   0.00000   0.00000        15
#            3    1.00000   0.04348   0.08333        23
#
#     accuracy                        0.27174       184
#    macro avg    0.47325   0.22456   0.14460       184
# weighted avg    0.50765   0.27174   0.17276       184
#
# Random State 22
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.027	0.057	0.037	-0.030	0.006	0.215
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29677   0.82143   0.43602        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.20000   0.04348   0.07143        23
#
#     accuracy                        0.26087       184
#    macro avg    0.20753   0.21900   0.13224       184
# weighted avg    0.27837   0.26087   0.15215       184
#
# Random State 23
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.023	0.054	0.032	-0.028	0.001	0.009
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29114   0.82143   0.42991        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15612   0.20813   0.11285       184
# weighted avg    0.25165   0.25543   0.14136       184
#
# Random State 24
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.015	0.039	0.021	-0.009	-0.001	0.293
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.28750   0.82143   0.42593        56
#            1    0.25000   0.01111   0.02128        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.13437   0.20813   0.11180       184
# weighted avg    0.20978   0.25543   0.14004       184
#
# Random State 25
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.05s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.022	0.051	0.031	-0.022	0.000	0.024
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29299   0.82143   0.43192        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15658   0.20813   0.11336       184
# weighted avg    0.25222   0.25543   0.14197       184
#
# Random State 26
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.07s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.015	0.153	0.028	0.006	0.004	0.520
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.15833   0.24385   0.11978       184
# weighted avg    0.25435   0.29891   0.14980       184
#
# Random State 27
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.023	0.054	0.032	-0.028	0.001	0.009
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29114   0.82143   0.42991        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15612   0.20813   0.11285       184
# weighted avg    0.25165   0.25543   0.14136       184
#
# Random State 28
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.018	0.101	0.031	-0.011	0.005	0.008
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30682   0.96429   0.46552        56
#            1    0.25000   0.01111   0.02128        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.13920   0.24385   0.12170       184
# weighted avg    0.21566   0.29891   0.15209       184
#
# Random State 29
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Discritize	0.03s	0.022	0.049	0.030	-0.022	-0.001	0.022
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29299   0.82143   0.43192        56
#            1    0.25000   0.01111   0.02128        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.13575   0.20813   0.11330       184
# weighted avg    0.21145   0.25543   0.14186       184
#
# Random State 30
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.019	0.118	0.033	-0.019	0.007	-0.004
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30508   0.96429   0.46352        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.15960   0.24385   0.12126       184
# weighted avg    0.25590   0.29891   0.15159       184
#
# Random State 31
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.02s	0.016	0.039	0.023	-0.020	0.001	0.270
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29299   0.82143   0.43192        56
#            1    0.25000   0.01111   0.02128        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.13575   0.20813   0.11330       184
# weighted avg    0.21145   0.25543   0.14186       184
#
# Random State 32
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.009	0.034	0.014	-0.004	-0.011	0.296
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29825   0.91071   0.44934        56
#            1    0.25000   0.01111   0.02128        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.28261       184
#    macro avg    0.13706   0.23046   0.11765       184
# weighted avg    0.21305   0.28261   0.14716       184
#
# Random State 33
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.027	0.057	0.037	-0.030	0.006	0.215
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29677   0.82143   0.43602        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.09524   0.08696   0.09091        23
#
#     accuracy                        0.26630       184
#    macro avg    0.18134   0.22987   0.13711       184
# weighted avg    0.26527   0.26630   0.15458       184
#
# Random State 34
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.05s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.015	0.153	0.028	0.006	0.004	0.520
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.15833   0.24385   0.11978       184
# weighted avg    0.25435   0.29891   0.14980       184
#
# Random State 35
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.017	0.095	0.029	-0.011	0.003	0.299
# __________________________________________________________________________________
# Cosine Affinity
# ...
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30682   0.96429   0.46552        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.16004   0.24385   0.12176       184
# weighted avg    0.25642   0.29891   0.15220       184
#
# Random State 40
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.029	0.064	0.040	-0.036	0.010	0.022
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29487   0.82143   0.43396        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15705   0.20813   0.11387       184
# weighted avg    0.25279   0.25543   0.14259       184
#
# Random State 41
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.05s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.013	0.091	0.023	-0.003	-0.003	0.412
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30337   0.96429   0.46154        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.15918   0.24385   0.12076       184
# weighted avg    0.25537   0.29891   0.15099       184
#
# Random State 42
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.04s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.05s	0.018	0.108	0.031	-0.011	0.008	0.306
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30682   0.96429   0.46552        56
#            1    0.71429   0.05556   0.10309        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.32065       184
#    macro avg    0.25528   0.25496   0.14215       184
# weighted avg    0.44276   0.32065   0.19210       184
#
# Random State 43
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.027	0.059	0.037	-0.028	0.005	0.027
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29936   0.83929   0.44131        56
#            1    0.25000   0.01111   0.02128        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.10526   0.08696   0.09524        23
#
#     accuracy                        0.27174       184
#    macro avg    0.16366   0.23434   0.13946       184
# weighted avg    0.22655   0.27174   0.15662       184
#
# Random State 44
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.05s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.012	0.100	0.022	-0.010	-0.004	-0.020
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30168   0.96429   0.45957        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.15875   0.24385   0.12027       184
# weighted avg    0.25486   0.29891   0.15039       184
#
# Random State 45
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.017	0.095	0.029	-0.011	0.003	0.299
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30682   0.96429   0.46552        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.16004   0.24385   0.12176       184
# weighted avg    0.25642   0.29891   0.15220       184
#
# Random State 46
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.04s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.029	0.062	0.039	-0.030	0.009	0.037
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.29677   0.82143   0.43602        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15753   0.20813   0.11438       184
# weighted avg    0.25337   0.25543   0.14322       184
#
# Random State 47
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.05s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.05s	0.015	0.042	0.022	-0.010	0.001	0.311
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.28750   0.82143   0.42593        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.25543       184
#    macro avg    0.15521   0.20813   0.11186       184
# weighted avg    0.25054   0.25543   0.14015       184
#
# Random State 48
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.03s	0.015	0.153	0.028	0.006	0.004	0.520
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.15833   0.24385   0.11978       184
# weighted avg    0.25435   0.29891   0.14980       184
#
# Random State 49
# __________________________________________________________________________________
# init		time	homo	compl	v-meas	ARI	AMI	silhouette
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# K-Means  	0.06s	0.024	0.222	0.043	0.007	0.012	0.393
# Discritize	0.04s	0.015	0.153	0.028	0.006	0.004	0.520
# __________________________________________________________________________________
# Cosine Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.00000   0.00000   0.00000        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29348       184
#    macro avg    0.07500   0.24107   0.11441       184
# weighted avg    0.09130   0.29348   0.13928       184
#
# Euclidean Affinity
#               precision    recall  f1-score   support
#
#            0    0.30000   0.96429   0.45763        56
#            1    0.33333   0.01111   0.02151        90
#            2    0.00000   0.00000   0.00000        15
#            3    0.00000   0.00000   0.00000        23
#
#     accuracy                        0.29891       184
#    macro avg    0.15833   0.24385   0.11978       184
# weighted avg    0.25435   0.29891   0.14980       184
# C:\Users\MANIKANDAN\Anaconda2\envs\dl-env\lib\site-packages\sklearn\metrics\_classification.py:1268: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
